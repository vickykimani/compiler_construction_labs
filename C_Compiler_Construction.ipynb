# %% [markdown]
# <a href="https://colab.research.google.com/github/vickykimani/compiler_construction_labs/blob/main/C_Compiler_Construction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Group Members**

# %% [markdown]
# 1. 121289 - Atonya Whitney A. Madafali
# 2. 121472 - Kimani, Vicky Nightingale
# 3. 114439 - Laura Ayushi Ochieng'
# 4. 121720 - Mutungi Vincent Mugambi

# %% [markdown]
# # **Question 1**

# %% [markdown]
# ***Write the three address code (TAC) of the following:***

# %% [markdown]
# ***a. Any if-statment of your choice***

# %%
/**An example of an if-statement in C++ programming **/
#include <iostream>

using namespace std;

int main()
{
    int a, b, c;
 
    if(a < 12){
        b = 5 * a;
    }else{
        c = 0;
    }

    return 0;
}

# %% [markdown]
# *The three address code for the above code is as follows:*

# %% [markdown]
# ![picone.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *The interpretation of the above three address code is as below:*

# %% [markdown]
# ![picthree.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ***b. Any for-loop of your choice***

# %%
/**An example of a for loop in C++ programming **/
#include <iostream>

using namespace std;

int main()
{
    int a, i;
    
    /**For loop code in C++**/
    for( i = 0; i < 18; i++){
     a = 2 * i; 
    }

    return 0;
}

# %% [markdown]
# *The three address code for the above code is as shown below:*

# %% [markdown]
# ![picfive.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *The interpretation of the above TAC is as follows:*

# %% [markdown]
# ![picfour.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ***c. Any while-loop of your choice***

# %%
/**An example of a while loop in C++ programming **/
#include <iostream>

using namespace std;

int main()
{
    int x = 0;
    int y;
    while(x < 15){
        y = 8 + i;
        i ++;
    }
    
    return 0;
}

# %% [markdown]
# *The three address code for the above code is as shown below.*

# %% [markdown]
# ![pics.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *The interpretation of the above TAC is as follows:*

# %% [markdown]
# ![piceight.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # **Question 2**

# %% [markdown]
# *Write the triple implementation of one of the TAC's in question 1 above.*

# %% [markdown]
# ![tac_implementation_image.png](data:image/png;base64,...)
