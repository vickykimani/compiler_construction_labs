# %% [markdown]
# <a href="https://colab.research.google.com/github/vickykimani/compiler_construction_labs/blob/main/C_Compiler_Construction_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Group Members**
#
#
# 1.   121289 - Atonya Whitney A. Madafali
# 2.   121472 - Kimani, Vicky Nightingale
# 3.   114439 - Laura Ayushi Ochieng'
# 4.   120921 - Owino Michael
# 5.   121720 - Mutungi Vincent Mugambi

# %% [markdown]
# # **Question One**

# %% [markdown]
# *Using an example or illustration, explain what is predictive pars*ing?

# %% [markdown]
# Predictive parsing is a type of recursive descent parsing that does not require backtracking and can predict which products to use to replace the input string. Table-driven non-recursive predictive parsing is also referred to as LL(1) parser.
# To accomplish its tasks, the predictive parser uses a look-ahead pointer, which points to the next input symbols. To make the parser back-tracking free, the predictive parser puts some constraints on the grammar and accepts only a class of grammar known as LL(k) grammar.

# %% [markdown]
# ![predictive_parsing.png](data:image/png;base64,...)

# %% [markdown]
# # **Question Two**
# As an extension to question 1,
#
# 1.   What is LL (1) parsing?
#
# LL(1) parsing is a top-down parsing method on recursive-descent parsers constructed for a class of grammars.
#
# The first "L" in LL(1) stands for scanning the input from left to right, the second "L" for producing the leftmost derivation, and the "1" for using one input symbol of lookahead at each step to make parsing action decisions.
#
# 2.   Why do we get the First () and Follow () i.e. what do these two functions really represent?
#
# During top down parsing, first and follow allow us to choose which production to apply based on the next input symbol.
#
# Benefits of  first() and follow() include:
# * They can be used to prove the LL (K) characteristic of grammar.
#
# * They can be used to promote in the construction of predictive parsing tables.
#
# * They provides selection information for recursive descent parsers.
#
#
# first()− It is a function that gives the set of terminals that begin the strings derived from the production rule.
#
# follow() - for nonterminal A, to be the set of terminals a that can appear immediately to the right of A in some sentential form, that is, the set of terminals a such that there exists a derivation of the form SÞaAab for some a and b. Note that there may, at some time during the derivation, have been symbols between A and a, but if so, they derived e and disappeared. If A can be the rightmost symbol in some sentential form, then $, representing the input right endmarker, is in FOLLOW(A)

# %% [markdown]
# ## **Question Three**
# **Are there any unique attributes associated with Top-Down parsing?**
#
#
# 1.   Recursive-Descent Parsing
#
# A recursive-descent parsing program consists of a set of procedures, one for eachnonterminal. Execution begins with the procedure for the start symbol, whichhalts and announces success if its procedure body scans the entire input string.
#
# 2.   Nonrecursive Predict Parsing
#
# A nonrecursive predictive parser can be built by maintaining a stack explicitly, rather than implicitly via recursive calls. The parser mimics a leftmost derivation.

# %% [markdown]
# # **References**

# %% [markdown]
# 1. Shubrajit et al., ‘Non RECURSIVE PREDICTIVE PARSER’.
# 2. Aho, A., Lam, M., Sethi, R., & Ullman, J. (1986). Compilers: Principles, Techniques, & Tools (Second).
